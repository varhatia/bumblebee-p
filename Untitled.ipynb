# %%
import pandas
df1 = pandas.read_csv("files/Q3 Pipeline Snapshot.csv")
df1
# Out:
#                                   18 Character Opty Id  \
# 0                                   0060e00001tgmIjAAI
# 1                                   0060e00001tvNDSAA2
# 2                                   0060e00001rQnyGAAS
# 3                                   0060e00001s5ejhAAA
# 4                                   0060e00001s7icFAAQ
# 5                                   0060e00001t8gv2AAA
# 6                                   0060e00001qra1sAAA
# 7                                   0060e00001s5tpYAAQ
# 8                                   0060e00001s8JrdAAE
# 9                                   0060e00001t72CVAAY
# 10                                  0060e00001t8ONNAA2
# 11                                  0060e00001s6ql7AAA
# 12                                  0060e00001qqafPAAQ
# 13                                  0060e00001tgsAyAAI
# 14                                  0060e00001qqP0qAAE
# 15                                  0060e00001r2fDJAAY
# ...
